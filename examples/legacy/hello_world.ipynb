# %% [markdown]
# # Hello World E2E
# Run the terminal-compatible smoke flow from notebook context.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'scripts/hello_world_e2e.py', '--mode', 'notebook', '--dry-run'], check=True)
